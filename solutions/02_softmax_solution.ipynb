# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/02_softmax_solution.ipynb)
#
# # 🟢 Solution: Implement Softmax
#
# Reference solution for the numerically-stable Softmax function.
#
# $$\text{softmax}(x_i) = \frac{e^{x_i - \max(x)}}{\sum_j e^{x_j - \max(x)}}$$

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
# Out:
# f:\TorchCode\TorchCode\myenv\Lib\site-packages\torch\_subclasses\functional_tensor.py:362: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
# ✅ SOLUTION

def my_softmax(x: torch.Tensor, dim: int = -1) -> torch.Tensor:
    x_max = x.max(dim=dim, keepdim=True).values
    e_x = torch.exp(x - x_max)
    return e_x / e_x.sum(dim=dim, keepdim=True)

# %%
# Verify
x = torch.tensor([1.0, 2.0, 3.0])
print("Output:", my_softmax(x, dim=-1))
print("Sum:   ", my_softmax(x, dim=-1).sum())
print("Ref:   ", torch.softmax(x, dim=-1))
# Out:
# Output: tensor([0.0900, 0.2447, 0.6652])
# Sum:    tensor(1.)
# Ref:    tensor([0.0900, 0.2447, 0.6652])

# %%
import sys
import os

# تحديد المجلد الرئيسي للمشروع (المجلد الذي يحتوي على مجلد torch_judge)
# بما أن ملفات الحل في مجلد 'solutions'، فنحن نحتاج للرجوع للخلف خطوة واحدة
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
# Run judge
from torch_judge import check
check("softmax")
# Out:
# 🧪 Testing: Implement Softmax (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Basic 1-D (0.5ms)
#   ✅ [2/3] 2-D along dim=-1 (6.1ms)
#   ✅ [3/3] Numerical stability (4.4ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (10.9ms total)
#   Progress saved. Run status() to see your dashboard.
